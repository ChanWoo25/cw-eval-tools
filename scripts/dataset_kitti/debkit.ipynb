# %% [markdown]
# # KITTI Odometry Dataset

# %% [markdown]
# ## Import

# %%
import os
from io import TextIOWrapper
import sys
import struct
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.spatial.transform import Rotation
from pathlib import Path
from glob import glob
KITTI_ROOT = Path('/data/datasets/dataset_kitti')
KITTI_SEQS = ['00', '01', '02',
              '03', '04', '05', 
              '06', '07', '08',
              '09', '10']

# %% [markdown]
# ## Rearrage LiDAR

# %%
def rearrage_calib(root:Path, seq:str):
    old_calib_fn = root / 'data_odometry_calib' / 'dataset' / 'sequences' / seq / 'calib.txt'
    old_times_fn = root / 'data_odometry_calib' / 'dataset' / 'sequences' / seq / 'times.txt'
    new_calib_fn = root / seq / 'raw_calib.txt'
    new_times_fn = root / seq / 'raw_times.txt'
    if new_calib_fn.exists() :
        return False
    if new_times_fn.exists():
        return False
    
    # Rename
    os.rename(old_calib_fn, new_calib_fn)
    os.rename(old_times_fn, new_times_fn)
    return True

def rearrage_poses(root:Path, seq:str):
    old_poses_fn = root / 'data_odometry_poses' / 'dataset' / 'poses' / f'{seq}.txt'
    new_poses_fn = root / seq / 'raw_poses.txt'
    if new_poses_fn.exists():
        return False
    
    os.rename(old_poses_fn, new_poses_fn)
    return True

def rearrage_lidar(root:Path, seq:str):
    old_lidar_dir = root / seq / 'velodyne'
    new_lidar_dir = root / seq / 'lidar'
    old_paths = glob(f'{old_lidar_dir}/*.bin')
    new_paths = glob(f'{new_lidar_dir}/*.bin')
    old_N = len(old_paths)
    new_N = len(new_paths)
    if new_N != 0:
        print('Lidar is already re-arranged')
        return False
    
    old_paths.sort()
    os.makedirs(new_lidar_dir, exist_ok=True)
    for old_path in old_paths:
        old_fn = Path(old_path)
        new_fn = new_lidar_dir / old_fn.name
        print(new_fn)
        os.rename(old_fn, new_fn)
        
    return True

def rearrage_data(root:Path, seq:str):
    if not root.exists():
        print(f"{root} doesn't exist!")
        return False
    
    if not (root / seq ).exists():
        os.makedirs(root/seq)

    rearrage_calib(root, seq)
    rearrage_poses(root, seq)
    rearrage_lidar(root, seq)
    calib_fn = root / seq / 'raw_calib.txt'
    times_fn = root / seq / 'raw_times.txt'
    poses_fn = root / seq / 'raw_poses.txt'
    # calib = np.genfromtxt(calib_fn, dtype=float)
    times = np.genfromtxt(times_fn, dtype=float)
    poses = np.genfromtxt(poses_fn, dtype=float)
    print('timestamps: ', times.shape)
    print('poses: ', poses.shape)
    
    lidar_dir = root / seq / 'lidar'
    lidar_fns = glob(f'{lidar_dir}/*.bin')
    lidar_fns.sort()
    N_SCANS = len(lidar_fns)
    print(f"N_SCANS: {N_SCANS}")
    
    assert (N_SCANS == times.shape[0])
    assert (N_SCANS == poses.shape[0])
    
    data_pose_fn = root / seq / 'pose.txt'
    f_pose = open(data_pose_fn, 'w')
    for i in range(N_SCANS):
        time = times[i]
        pose = poses[i]
        rot_mat = np.array([pose[0:3],
                            pose[4:7],
                            pose[8:11]])
        # print(rot_mat.shape)
        rot_mat = Rotation.from_matrix(rot_mat)
        quat = rot_mat.as_quat() # x, y, z, w
        # print(quat.shape)
        trans = pose[3::4]
        # print(trans.shape)
        line = f"{time:.6f} {trans[0]:.6f} {trans[1]:.6f} {trans[2]:.6f} {quat[0]:.6f} {quat[1]:.6f} {quat[2]:.6f} {quat[3]:.6f}\n"
        f_pose.write(line)
    f_pose.close()
    
    lidar_data_fn = root / seq / 'lidar_data.txt'
    f_lidar = open(lidar_data_fn, 'w')
    for i in range(N_SCANS):
        time = times[i]
        lidar_fn = Path(lidar_fns[i])
        line = f"{time:.6f} lidar/{lidar_fn.name}\n"
        f_lidar.write(line)
    f_lidar.close()
    
    return True
        
        
    
    
    old_pose_fn = root / seq / 'old_pose.txt'  
    
    # Rename
    os.rename(pose_fn, old_pose_fn)
    
    
    # Parse Timestamps
    timestamps = np.genfromtxt(old_times_fn)
    print('timestamps: ', timestamps.shape)
    
    
    f_pose = open(pose_fn, 'r')
    f_data = open(lidar_data_fn, 'w')
        
    os.makedirs(new_lidar_dir, exist_ok=True)
    poses = f_pose.readlines()
    
    
    scan_paths = glob(f"{old_lidar_dir}/*.bin")
    scan_paths.sort()
    assert(len(scan_paths) == len(poses))
    
    for i in range(len(scan_paths)):
        print(scan_paths[i])
        print(poses[i])
        
        words = poses[i].split(' ')
        t = float(words[0])
        px = float(words[1])
        py = float(words[2])
        pz = float(words[3])
        
        if i == 5:
            break
    
    return True
    
    # timestamps = []
    # for scan_path in scan_paths:
    #     timestamp = float(Path(scan_path).name.split('.')[0]) / 1e6
    #     timestamps.append(timestamp)
    #     if len(timestamps) >= 2:
    #         if timestamps[-2] >= timestamps[-1]:
    #             print("Time order is wrong!")
    #             return False
    
    # assert (len(timestamps) == len(scan_paths))
    
    # for index in range(len(timestamps)):
    #     line = f"{timestamps[index]:.6f} lidar/{index:06d}.bin\n"
    #     old_scan_fn = scan_paths[index]
    #     new_scan_fn = f"{new_lidar_dir}/{index:06d}.bin"
    #     # print(old_scan_fn)
    #     # print(new_scan_fn)
    #     os.rename(old_scan_fn, new_scan_fn)
    #     f_data.write(line)

    # f_data.close()
    # return True

# %%
for seq in KITTI_SEQS:
    rearrage_data(KITTI_ROOT, seq)
# Out:
# Lidar is already re-arranged
# timestamps:  (4541,)
# poses:  (4541, 12)
# N_SCANS: 4541
# Lidar is already re-arranged
# timestamps:  (1101,)
# poses:  (1101, 12)
# N_SCANS: 1101
# /data/datasets/dataset_kitti/02/lidar/000000.bin
# /data/datasets/dataset_kitti/02/lidar/000001.bin
# /data/datasets/dataset_kitti/02/lidar/000002.bin
# /data/datasets/dataset_kitti/02/lidar/000003.bin
# /data/datasets/dataset_kitti/02/lidar/000004.bin
# /data/datasets/dataset_kitti/02/lidar/000005.bin
# /data/datasets/dataset_kitti/02/lidar/000006.bin
# /data/datasets/dataset_kitti/02/lidar/000007.bin
# /data/datasets/dataset_kitti/02/lidar/000008.bin
# /data/datasets/dataset_kitti/02/lidar/000009.bin
# /data/datasets/dataset_kitti/02/lidar/000010.bin
# /data/datasets/dataset_kitti/02/lidar/000011.bin
# /data/datasets/dataset_kitti/02/lidar/000012.bin
# /data/datasets/dataset_kitti/02/lidar/000013.bin
# /data/datasets/dataset_kitti/02/lidar/000014.bin
# /data/datasets/dataset_kitti/02/lidar/000015.bin
# /data/datasets/dataset_kitti/02/lidar/000016.bin
# /data/datasets/dataset_kitti/02/lidar/000017.bin
# /data/datasets/dataset_kitti/02/lidar/000018.bin
# /data/datasets/dataset_kitti/02/lidar/000019.bin
# /data/datasets/dataset_kitti/02/lidar/000020.bin
# /data/datasets/dataset_kitti/02/lidar/000021.bin
# /data/datasets/dataset_kitti/02/lidar/000022.bin
# /data/datasets/dataset_kitti/02/lidar/000023.bin
# /data/datasets/dataset_kitti/02/lidar/000024.bin
# /data/datasets/dataset_kitti/02/lidar/000025.bin
# /data/datasets/dataset_kitti/02/lidar/000026.bin
# /data/datasets/dataset_kitti/02/lidar/000027.bin
# /data/datasets/dataset_kitti/02/lidar/000028.bin
# /data/datasets/dataset_kitti/02/lidar/000029.bin
# /data/datasets/dataset_kitti/02/lidar/000030.bin
# /data/datasets/dataset_kitti/02/lidar/000031.bin
# /data/datasets/dataset_kitti/02/lidar/000032.bin
# /data/datasets/dataset_kitti/02/lidar/000033.bin
# /data/datasets/dataset_kitti/02/lidar/000034.bin
# /data/datasets/dataset_kitti/02/lidar/000035.bin
# /data/datasets/dataset_kitti/02/lidar/000036.bin
# /data/datasets/dataset_kitti/02/lidar/000037.bin
# /data/datasets/dataset_kitti/02/lidar/000038.bin
# /data/datasets/dataset_kitti/02/lidar/000039.bin
# /data/datasets/dataset_kitti/02/lidar/000040.bin
# /data/datasets/dataset_kitti/02/lidar/000041.bin
# /data/datasets/dataset_kitti/02/lidar/000042.bin
# /data/datasets/dataset_kitti/02/lidar/000043.bin
# /data/datasets/dataset_kitti/02/lidar/000044.bin
# /data/datasets/dataset_kitti/02/lidar/000045.bin
# /data/datasets/dataset_kitti/02/lidar/000046.bin
# /data/datasets/dataset_kitti/02/lidar/000047.bin
# /data/datasets/dataset_kitti/02/lidar/000048.bin
# /data/datasets/dataset_kitti/02/lidar/000049.bin
# /data/datasets/dataset_kitti/02/lidar/000050.bin
# /data/datasets/dataset_kitti/02/lidar/000051.bin
# /data/datasets/dataset_kitti/02/lidar/000052.bin
# /data/datasets/dataset_kitti/02/lidar/000053.bin
# /data/datasets/dataset_kitti/02/lidar/000054.bin
# /data/datasets/dataset_kitti/02/lidar/000055.bin
# /data/datasets/dataset_kitti/02/lidar/000056.bin
# /data/datasets/dataset_kitti/02/lidar/000057.bin
# /data/datasets/dataset_kitti/02/lidar/000058.bin
# /data/datasets/dataset_kitti/02/lidar/000059.bin
# /data/datasets/dataset_kitti/02/lidar/000060.bin
# /data/datasets/dataset_kitti/02/lidar/000061.bin
# /data/datasets/dataset_kitti/02/lidar/000062.bin
# /data/datasets/dataset_kitti/02/lidar/000063.bin
# /data/datasets/dataset_kitti/02/lidar/000064.bin
# /data/datasets/dataset_kitti/02/lidar/000065.bin
# /data/datasets/dataset_kitti/02/lidar/000066.bin
# /data/datasets/dataset_kitti/02/lidar/000067.bin
# /data/datasets/dataset_kitti/02/lidar/000068.bin
# /data/datasets/dataset_kitti/02/lidar/000069.bin
# /data/datasets/dataset_kitti/02/lidar/000070.bin
# /data/datasets/dataset_kitti/02/lidar/000071.bin
# /data/datasets/dataset_kitti/02/lidar/000072.bin
# /data/datasets/dataset_kitti/02/lidar/000073.bin
# /data/datasets/dataset_kitti/02/lidar/000074.bin
# /data/datasets/dataset_kitti/02/lidar/000075.bin
# /data/datasets/dataset_kitti/02/lidar/000076.bin
# /data/datasets/dataset_kitti/02/lidar/000077.bin
# /data/datasets/dataset_kitti/02/lidar/000078.bin
# /data/datasets/dataset_kitti/02/lidar/000079.bin
# /data/datasets/dataset_kitti/02/lidar/000080.bin
# /data/datasets/dataset_kitti/02/lidar/000081.bin
# /data/datasets/dataset_kitti/02/lidar/000082.bin
# /data/datasets/dataset_kitti/02/lidar/000083.bin
# /data/datasets/dataset_kitti/02/lidar/000084.bin
# /data/datasets/dataset_kitti/02/lidar/000085.bin
# /data/datasets/dataset_kitti/02/lidar/000086.bin
# /data/datasets/dataset_kitti/02/lidar/000087.bin
# /data/datasets/dataset_kitti/02/lidar/000088.bin
# /data/datasets/dataset_kitti/02/lidar/000089.bin
# /data/datasets/dataset_kitti/02/lidar/000090.bin
# /data/datasets/dataset_kitti/02/lidar/000091.bin
# /data/datasets/dataset_kitti/02/lidar/000092.bin
# /data/datasets/dataset_kitti/02/lidar/000093.bin
# /data/datasets/dataset_kitti/02/lidar/000094.bin
# /data/datasets/dataset_kitti/02/lidar/000095.bin
# /data/datasets/dataset_kitti/02/lidar/000096.bin
# /data/datasets/dataset_kitti/02/lidar/000097.bin
# /data/datasets/dataset_kitti/02/lidar/000098.bin
# /data/datasets/dataset_kitti/02/lidar/000099.bin
# /data/datasets/dataset_kitti/02/lidar/000100.bin
# /data/datasets/dataset_kitti/02/lidar/000101.bin
# /data/datasets/dataset_kitti/02/lidar/000102.bin
# /data/datasets/dataset_kitti/02/lidar/000103.bin
# /data/datasets/dataset_kitti/02/lidar/000104.bin
# /data/datasets/dataset_kitti/02/lidar/000105.bin
# /data/datasets/dataset_kitti/02/lidar/000106.bin
# /data/datasets/dataset_kitti/02/lidar/000107.bin
# /data/datasets/dataset_kitti/02/lidar/000108.bin
# /data/datasets/dataset_kitti/02/lidar/000109.bin
# /data/datasets/dataset_kitti/02/lidar/000110.bin
# /data/datasets/dataset_kitti/02/lidar/000111.bin
# /data/datasets/dataset_kitti/02/lidar/000112.bin
# /data/datasets/dataset_kitti/02/lidar/000113.bin
# /data/datasets/dataset_kitti/02/lidar/000114.bin
# /data/datasets/dataset_kitti/02/lidar/000115.bin
# /data/datasets/dataset_kitti/02/lidar/000116.bin
# /data/datasets/dataset_kitti/02/lidar/000117.bin
# /data/datasets/dataset_kitti/02/lidar/000118.bin
# /data/datasets/dataset_kitti/02/lidar/000119.bin
# /data/datasets/dataset_kitti/02/lidar/000120.bin
# /data/datasets/dataset_kitti/02/lidar/000121.bin
# /data/datasets/dataset_kitti/02/lidar/000122.bin
# /data/datasets/dataset_kitti/02/lidar/000123.bin
# /data/datasets/dataset_kitti/02/lidar/000124.bin
# /data/datasets/dataset_kitti/02/lidar/000125.bin
# /data/datasets/dataset_kitti/02/lidar/000126.bin
# /data/datasets/dataset_kitti/02/lidar/000127.bin
# /data/datasets/dataset_kitti/02/lidar/000128.bin
# /data/datasets/dataset_kitti/02/lidar/000129.bin
# /data/datasets/dataset_kitti/02/lidar/000130.bin
# /data/datasets/dataset_kitti/02/lidar/000131.bin
# /data/datasets/dataset_kitti/02/lidar/000132.bin
# /data/datasets/dataset_kitti/02/lidar/000133.bin
# /data/datasets/dataset_kitti/02/lidar/000134.bin
# /data/datasets/dataset_kitti/02/lidar/000135.bin
# /data/datasets/dataset_kitti/02/lidar/000136.bin
# /data/datasets/dataset_kitti/02/lidar/000137.bin
# /data/datasets/dataset_kitti/02/lidar/000138.bin
# /data/datasets/dataset_kitti/02/lidar/000139.bin
# /data/datasets/dataset_kitti/02/lidar/000140.bin
# /data/datasets/dataset_kitti/02/lidar/000141.bin
# /data/datasets/dataset_kitti/02/lidar/000142.bin
# /data/datasets/dataset_kitti/02/lidar/000143.bin
# /data/datasets/dataset_kitti/02/lidar/000144.bin
# /data/datasets/dataset_kitti/02/lidar/000145.bin
# /data/datasets/dataset_kitti/02/lidar/000146.bin
# /data/datasets/dataset_kitti/02/lidar/000147.bin
# /data/datasets/dataset_kitti/02/lidar/000148.bin
# /data/datasets/dataset_kitti/02/lidar/000149.bin
# /data/datasets/dataset_kitti/02/lidar/000150.bin
# /data/datasets/dataset_kitti/02/lidar/000151.bin
# /data/datasets/dataset_kitti/02/lidar/000152.bin
# /data/datasets/dataset_kitti/02/lidar/000153.bin
# /data/datasets/dataset_kitti/02/lidar/000154.bin
# /data/datasets/dataset_kitti/02/lidar/000155.bin
# /data/datasets/dataset_kitti/02/lidar/000156.bin
# /data/datasets/dataset_kitti/02/lidar/000157.bin
# /data/datasets/dataset_kitti/02/lidar/000158.bin
# /data/datasets/dataset_kitti/02/lidar/000159.bin
# /data/datasets/dataset_kitti/02/lidar/000160.bin
# /data/datasets/dataset_kitti/02/lidar/000161.bin
# /data/datasets/dataset_kitti/02/lidar/000162.bin
# /data/datasets/dataset_kitti/02/lidar/000163.bin
# /data/datasets/dataset_kitti/02/lidar/000164.bin
# /data/datasets/dataset_kitti/02/lidar/000165.bin
# /data/datasets/dataset_kitti/02/lidar/000166.bin
# /data/datasets/dataset_kitti/02/lidar/000167.bin
# /data/datasets/dataset_kitti/02/lidar/000168.bin
# /data/datasets/dataset_kitti/02/lidar/000169.bin
# /data/datasets/dataset_kitti/02/lidar/000170.bin
# /data/datasets/dataset_kitti/02/lidar/000171.bin
# /data/datasets/dataset_kitti/02/lidar/000172.bin
# /data/datasets/dataset_kitti/02/lidar/000173.bin
# /data/datasets/dataset_kitti/02/lidar/000174.bin
# /data/datasets/dataset_kitti/02/lidar/000175.bin
# /data/datasets/dataset_kitti/02/lidar/000176.bin
# /data/datasets/dataset_kitti/02/lidar/000177.bin
# /data/datasets/dataset_kitti/02/lidar/000178.bin
# /data/datasets/dataset_kitti/02/lidar/000179.bin
# /data/datasets/dataset_kitti/02/lidar/000180.bin
# /data/datasets/dataset_kitti/02/lidar/000181.bin
# /data/datasets/dataset_kitti/02/lidar/000182.bin
# /data/datasets/dataset_kitti/02/lidar/000183.bin
# /data/datasets/dataset_kitti/02/lidar/000184.bin
# /data/datasets/dataset_kitti/02/lidar/000185.bin
# /data/datasets/dataset_kitti/02/lidar/000186.bin
# /data/datasets/dataset_kitti/02/lidar/000187.bin
# /data/datasets/dataset_kitti/02/lidar/000188.bin
# /data/datasets/dataset_kitti/02/lidar/000189.bin
# /data/datasets/dataset_kitti/02/lidar/000190.bin
# /data/datasets/dataset_kitti/02/lidar/000191.bin
# /data/datasets/dataset_kitti/02/lidar/000192.bin
# /data/datasets/dataset_kitti/02/lidar/000193.bin
# /data/datasets/dataset_kitti/02/lidar/000194.bin
# /data/datasets/dataset_kitti/02/lidar/000195.bin
# /data/datasets/dataset_kitti/02/lidar/000196.bin
# /data/datasets/dataset_kitti/02/lidar/000197.bin
# /data/datasets/dataset_kitti/02/lidar/000198.bin
# /data/datasets/dataset_kitti/02/lidar/000199.bin
# /data/datasets/dataset_kitti/02/lidar/000200.bin
# /data/datasets/dataset_kitti/02/lidar/000201.bin
# /data/datasets/dataset_kitti/02/lidar/000202.bin
# /data/datasets/dataset_kitti/02/lidar/000203.bin
# /data/datasets/dataset_kitti/02/lidar/000204.bin
# /data/datasets/dataset_kitti/02/lidar/000205.bin
# /data/datasets/dataset_kitti/02/lidar/000206.bin
# /data/datasets/dataset_kitti/02/lidar/000207.bin
# /data/datasets/dataset_kitti/02/lidar/000208.bin
# /data/datasets/dataset_kitti/02/lidar/000209.bin
# /data/datasets/dataset_kitti/02/lidar/000210.bin
# /data/datasets/dataset_kitti/02/lidar/000211.bin
# /data/datasets/dataset_kitti/02/lidar/000212.bin
# /data/datasets/dataset_kitti/02/lidar/000213.bin
# /data/datasets/dataset_kitti/02/lidar/000214.bin
# /data/datasets/dataset_kitti/02/lidar/000215.bin
# /data/datasets/dataset_kitti/02/lidar/000216.bin
# /data/datasets/dataset_kitti/02/lidar/000217.bin
# /data/datasets/dataset_kitti/02/lidar/000218.bin
# /data/datasets/dataset_kitti/02/lidar/000219.bin
# /data/datasets/dataset_kitti/02/lidar/000220.bin
# /data/datasets/dataset_kitti/02/lidar/000221.bin
# /data/datasets/dataset_kitti/02/lidar/000222.bin
# /data/datasets/dataset_kitti/02/lidar/000223.bin
# /data/datasets/dataset_kitti/02/lidar/000224.bin
# /data/datasets/dataset_kitti/02/lidar/000225.bin
# /data/datasets/dataset_kitti/02/lidar/000226.bin
# /data/datasets/dataset_kitti/02/lidar/000227.bin
# /data/datasets/dataset_kitti/02/lidar/000228.bin
# /data/datasets/dataset_kitti/02/lidar/000229.bin
# /data/datasets/dataset_kitti/02/lidar/000230.bin
# /data/datasets/dataset_kitti/02/lidar/000231.bin
# /data/datasets/dataset_kitti/02/lidar/000232.bin
# /data/datasets/dataset_kitti/02/lidar/000233.bin
# /data/datasets/dataset_kitti/02/lidar/000234.bin
# /data/datasets/dataset_kitti/02/lidar/000235.bin
# /data/datasets/dataset_kitti/02/lidar/000236.bin
# /data/datasets/dataset_kitti/02/lidar/000237.bin
# /data/datasets/dataset_kitti/02/lidar/000238.bin
# /data/datasets/dataset_kitti/02/lidar/000239.bin
# /data/datasets/dataset_kitti/02/lidar/000240.bin
# /data/datasets/dataset_kitti/02/lidar/000241.bin
# /data/datasets/dataset_kitti/02/lidar/000242.bin
# /data/datasets/dataset_kitti/02/lidar/000243.bin
# /data/datasets/dataset_kitti/02/lidar/000244.bin
# /data/datasets/dataset_kitti/02/lidar/000245.bin
# /data/datasets/dataset_kitti/02/lidar/000246.bin
# /data/datasets/dataset_kitti/02/lidar/000247.bin
# /data/datasets/dataset_kitti/02/lidar/000248.bin
# /data/datasets/dataset_kitti/02/lidar/000249.bin
# /data/datasets/dataset_kitti/02/lidar/000250.bin
# /data/datasets/dataset_kitti/02/lidar/000251.bin
# /data/datasets/dataset_kitti/02/lidar/000252.bin
# /data/datasets/dataset_kitti/02/lidar/000253.bin
# /data/datasets/dataset_kitti/02/lidar/000254.bin
# /data/datasets/dataset_kitti/02/lidar/000255.bin
# /data/datasets/dataset_kitti/02/lidar/000256.bin
# /data/datasets/dataset_kitti/02/lidar/000257.bin
# /data/datasets/dataset_kitti/02/lidar/000258.bin
# /data/datasets/dataset_kitti/02/lidar/000259.bin
# /data/datasets/dataset_kitti/02/lidar/000260.bin
# /data/datasets/dataset_kitti/02/lidar/000261.bin
# /data/datasets/dataset_kitti/02/lidar/000262.bin
# /data/datasets/dataset_kitti/02/lidar/000263.bin
# /data/datasets/dataset_kitti/02/lidar/000264.bin
# /data/datasets/dataset_kitti/02/lidar/000265.bin
# /data/datasets/dataset_kitti/02/lidar/000266.bin
# /data/datasets/dataset_kitti/02/lidar/000267.bin
# /data/datasets/dataset_kitti/02/lidar/000268.bin
# /data/datasets/dataset_kitti/02/lidar/000269.bin
# /data/datasets/dataset_kitti/02/lidar/000270.bin
# /data/datasets/dataset_kitti/02/lidar/000271.bin
# /data/datasets/dataset_kitti/02/lidar/000272.bin
# /data/datasets/dataset_kitti/02/lidar/000273.bin
# /data/datasets/dataset_kitti/02/lidar/000274.bin
# /data/datasets/dataset_kitti/02/lidar/000275.bin
# /data/datasets/dataset_kitti/02/lidar/000276.bin
# /data/datasets/dataset_kitti/02/lidar/000277.bin
# /data/datasets/dataset_kitti/02/lidar/000278.bin
# /data/datasets/dataset_kitti/02/lidar/000279.bin
# /data/datasets/dataset_kitti/02/lidar/000280.bin
# /data/datasets/dataset_kitti/02/lidar/000281.bin
# /data/datasets/dataset_kitti/02/lidar/000282.bin
# /data/datasets/dataset_kitti/02/lidar/000283.bin
# /data/datasets/dataset_kitti/02/lidar/000284.bin
# /data/datasets/dataset_kitti/02/lidar/000285.bin
# /data/datasets/dataset_kitti/02/lidar/000286.bin
# /data/datasets/dataset_kitti/02/lidar/000287.bin
# /data/datasets/dataset_kitti/02/lidar/000288.bin
# /data/datasets/dataset_kitti/02/lidar/000289.bin
# /data/datasets/dataset_kitti/02/lidar/000290.bin
# /data/datasets/dataset_kitti/02/lidar/000291.bin
# /data/datasets/dataset_kitti/02/lidar/000292.bin
# /data/datasets/dataset_kitti/02/lidar/000293.bin
# /data/datasets/dataset_kitti/02/lidar/000294.bin
# /data/datasets/dataset_kitti/02/lidar/000295.bin
# /data/datasets/dataset_kitti/02/lidar/000296.bin
# /data/datasets/dataset_kitti/02/lidar/000297.bin
# /data/datasets/dataset_kitti/02/lidar/000298.bin
# /data/datasets/dataset_kitti/02/lidar/000299.bin
# /data/datasets/dataset_kitti/02/lidar/000300.bin
# /data/datasets/dataset_kitti/02/lidar/000301.bin
# /data/datasets/dataset_kitti/02/lidar/000302.bin
# /data/datasets/dataset_kitti/02/lidar/000303.bin
# /data/datasets/dataset_kitti/02/lidar/000304.bin
# /data/datasets/dataset_kitti/02/lidar/000305.bin
# /data/datasets/dataset_kitti/02/lidar/000306.bin
# /data/datasets/dataset_kitti/02/lidar/000307.bin
# /data/datasets/dataset_kitti/02/lidar/000308.bin
# /data/datasets/dataset_kitti/02/lidar/000309.bin
# /data/datasets/dataset_kitti/02/lidar/000310.bin
# /data/datasets/dataset_kitti/02/lidar/000311.bin
# /data/datasets/dataset_kitti/02/lidar/000312.bin
# /data/datasets/dataset_kitti/02/lidar/000313.bin
# /data/datasets/dataset_kitti/02/lidar/000314.bin
# /data/datasets/dataset_kitti/02/lidar/000315.bin
# /data/datasets/dataset_kitti/02/lidar/000316.bin
# /data/datasets/dataset_kitti/02/lidar/000317.bin
# /data/datasets/dataset_kitti/02/lidar/000318.bin
# /data/datasets/dataset_kitti/02/lidar/000319.bin
# /data/datasets/dataset_kitti/02/lidar/000320.bin
# /data/datasets/dataset_kitti/02/lidar/000321.bin
# /data/datasets/dataset_kitti/02/lidar/000322.bin
# /data/datasets/dataset_kitti/02/lidar/000323.bin
# /data/datasets/dataset_kitti/02/lidar/000324.bin
# /data/datasets/dataset_kitti/02/lidar/000325.bin
# /data/datasets/dataset_kitti/02/lidar/000326.bin
# /data/datasets/dataset_kitti/02/lidar/000327.bin
# /data/datasets/dataset_kitti/02/lidar/000328.bin
# /data/datasets/dataset_kitti/02/lidar/000329.bin
# /data/datasets/dataset_kitti/02/lidar/000330.bin
# /data/datasets/dataset_kitti/02/lidar/000331.bin
# /data/datasets/dataset_kitti/02/lidar/000332.bin
# /data/datasets/dataset_kitti/02/lidar/000333.bin
# /data/datasets/dataset_kitti/02/lidar/000334.bin
# /data/datasets/dataset_kitti/02/lidar/000335.bin
# /data/datasets/dataset_kitti/02/lidar/000336.bin
# /data/datasets/dataset_kitti/02/lidar/000337.bin
# /data/datasets/dataset_kitti/02/lidar/000338.bin
# /data/datasets/dataset_kitti/02/lidar/000339.bin
# /data/datasets/dataset_kitti/02/lidar/000340.bin
# /data/datasets/dataset_kitti/02/lidar/000341.bin
# /data/datasets/dataset_kitti/02/lidar/000342.bin
# /data/datasets/dataset_kitti/02/lidar/000343.bin
# /data/datasets/dataset_kitti/02/lidar/000344.bin
# /data/datasets/dataset_kitti/02/lidar/000345.bin
# /data/datasets/dataset_kitti/02/lidar/000346.bin
# /data/datasets/dataset_kitti/02/lidar/000347.bin
# /data/datasets/dataset_kitti/02/lidar/000348.bin
# /data/datasets/dataset_kitti/02/lidar/000349.bin
# /data/datasets/dataset_kitti/02/lidar/000350.bin
# /data/datasets/dataset_kitti/02/lidar/000351.bin
# /data/datasets/dataset_kitti/02/lidar/000352.bin
# /data/datasets/dataset_kitti/02/lidar/000353.bin
# /data/datasets/dataset_kitti/02/lidar/000354.bin
# /data/datasets/dataset_kitti/02/lidar/000355.bin
# /data/datasets/dataset_kitti/02/lidar/000356.bin
# /data/datasets/dataset_kitti/02/lidar/000357.bin
# /data/datasets/dataset_kitti/02/lidar/000358.bin
# /data/datasets/dataset_kitti/02/lidar/000359.bin
# /data/datasets/dataset_kitti/02/lidar/000360.bin
# /data/datasets/dataset_kitti/02/lidar/000361.bin
# /data/datasets/dataset_kitti/02/lidar/000362.bin
# /data/datasets/dataset_kitti/02/lidar/000363.bin
# /data/datasets/dataset_kitti/02/lidar/000364.bin
# /data/datasets/dataset_kitti/02/lidar/000365.bin
# /data/datasets/dataset_kitti/02/lidar/000366.bin
# /data/datasets/dataset_kitti/02/lidar/000367.bin
# /data/datasets/dataset_kitti/02/lidar/000368.bin
# /data/datasets/dataset_kitti/02/lidar/000369.bin
# /data/datasets/dataset_kitti/02/lidar/000370.bin
# /data/datasets/dataset_kitti/02/lidar/000371.bin
# /data/datasets/dataset_kitti/02/lidar/000372.bin
# /data/datasets/dataset_kitti/02/lidar/000373.bin
# /data/datasets/dataset_kitti/02/lidar/000374.bin
# /data/datasets/dataset_kitti/02/lidar/000375.bin
# /data/datasets/dataset_kitti/02/lidar/000376.bin
# /data/datasets/dataset_kitti/02/lidar/000377.bin
# /data/datasets/dataset_kitti/02/lidar/000378.bin
# /data/datasets/dataset_kitti/02/lidar/000379.bin
# /data/datasets/dataset_kitti/02/lidar/000380.bin
# /data/datasets/dataset_kitti/02/lidar/000381.bin
# /data/datasets/dataset_kitti/02/lidar/000382.bin
# /data/datasets/dataset_kitti/02/lidar/000383.bin
# /data/datasets/dataset_kitti/02/lidar/000384.bin
# /data/datasets/dataset_kitti/02/lidar/000385.bin
# /data/datasets/dataset_kitti/02/lidar/000386.bin
# /data/datasets/dataset_kitti/02/lidar/000387.bin
# /data/datasets/dataset_kitti/02/lidar/000388.bin
# /data/datasets/dataset_kitti/02/lidar/000389.bin
# /data/datasets/dataset_kitti/02/lidar/000390.bin
# /data/datasets/dataset_kitti/02/lidar/000391.bin
# /data/datasets/dataset_kitti/02/lidar/000392.bin
# /data/datasets/dataset_kitti/02/lidar/000393.bin
# /data/datasets/dataset_kitti/02/lidar/000394.bin
# /data/datasets/dataset_kitti/02/lidar/000395.bin
# /data/datasets/dataset_kitti/02/lidar/000396.bin
# /data/datasets/dataset_kitti/02/lidar/000397.bin
# /data/datasets/dataset_kitti/02/lidar/000398.bin
# /data/datasets/dataset_kitti/02/lidar/000399.bin
# /data/datasets/dataset_kitti/02/lidar/000400.bin
# /data/datasets/dataset_kitti/02/lidar/000401.bin
# /data/datasets/dataset_kitti/02/lidar/000402.bin
# /data/datasets/dataset_kitti/02/lidar/000403.bin
# /data/datasets/dataset_kitti/02/lidar/000404.bin
# /data/datasets/dataset_kitti/02/lidar/000405.bin
# /data/datasets/dataset_kitti/02/lidar/000406.bin
# /data/datasets/dataset_kitti/02/lidar/000407.bin
# /data/datasets/dataset_kitti/02/lidar/000408.bin
# /data/datasets/dataset_kitti/02/lidar/000409.bin
# /data/datasets/dataset_kitti/02/lidar/000410.bin
# /data/datasets/dataset_kitti/02/lidar/000411.bin
# /data/datasets/dataset_kitti/02/lidar/000412.bin
# /data/datasets/dataset_kitti/02/lidar/000413.bin
# /data/datasets/dataset_kitti/02/lidar/000414.bin
# /data/datasets/dataset_kitti/02/lidar/000415.bin
# /data/datasets/dataset_kitti/02/lidar/000416.bin
# /data/datasets/dataset_kitti/02/lidar/000417.bin
# /data/datasets/dataset_kitti/02/lidar/000418.bin
# /data/datasets/dataset_kitti/02/lidar/000419.bin
# /data/datasets/dataset_kitti/02/lidar/000420.bin
# /data/datasets/dataset_kitti/02/lidar/000421.bin
# /data/datasets/dataset_kitti/02/lidar/000422.bin
# /data/datasets/dataset_kitti/02/lidar/000423.bin
# /data/datasets/dataset_kitti/02/lidar/000424.bin
# /data/datasets/dataset_kitti/02/lidar/000425.bin
# /data/datasets/dataset_kitti/02/lidar/000426.bin
# /data/datasets/dataset_kitti/02/lidar/000427.bin
# /data/datasets/dataset_kitti/02/lidar/000428.bin
# /data/datasets/dataset_kitti/02/lidar/000429.bin
# /data/datasets/dataset_kitti/02/lidar/000430.bin
# /data/datasets/dataset_kitti/02/lidar/000431.bin
# /data/datasets/dataset_kitti/02/lidar/000432.bin
# /data/datasets/dataset_kitti/02/lidar/000433.bin
# /data/datasets/dataset_kitti/02/lidar/000434.bin
# /data/datasets/dataset_kitti/02/lidar/000435.bin
# /data/datasets/dataset_kitti/02/lidar/000436.bin
# /data/datasets/dataset_kitti/02/lidar/000437.bin
# /data/datasets/dataset_kitti/02/lidar/000438.bin
# /data/datasets/dataset_kitti/02/lidar/000439.bin
# /data/datasets/dataset_kitti/02/lidar/000440.bin
# /data/datasets/dataset_kitti/02/lidar/000441.bin
# /data/datasets/dataset_kitti/02/lidar/000442.bin
# /data/datasets/dataset_kitti/02/lidar/000443.bin
# /data/datasets/dataset_kitti/02/lidar/000444.bin
# /data/datasets/dataset_kitti/02/lidar/000445.bin
# /data/datasets/dataset_kitti/02/lidar/000446.bin
# /data/datasets/dataset_kitti/02/lidar/000447.bin
# /data/datasets/dataset_kitti/02/lidar/000448.bin
# /data/datasets/dataset_kitti/02/lidar/000449.bin
# /data/datasets/dataset_kitti/02/lidar/000450.bin
# /data/datasets/dataset_kitti/02/lidar/000451.bin
# /data/datasets/dataset_kitti/02/lidar/000452.bin
# /data/datasets/dataset_kitti/02/lidar/000453.bin
# /data/datasets/dataset_kitti/02/lidar/000454.bin
# /data/datasets/dataset_kitti/02/lidar/000455.bin
# /data/datasets/dataset_kitti/02/lidar/000456.bin
# /data/datasets/dataset_kitti/02/lidar/000457.bin
# /data/datasets/dataset_kitti/02/lidar/000458.bin
# /data/datasets/dataset_kitti/02/lidar/000459.bin
# /data/datasets/dataset_kitti/02/lidar/000460.bin
# /data/datasets/dataset_kitti/02/lidar/000461.bin
# /data/datasets/dataset_kitti/02/lidar/000462.bin
# /data/datasets/dataset_kitti/02/lidar/000463.bin
# /data/datasets/dataset_kitti/02/lidar/000464.bin
# /data/datasets/dataset_kitti/02/lidar/000465.bin
# /data/datasets/dataset_kitti/02/lidar/000466.bin
# /data/datasets/dataset_kitti/02/lidar/000467.bin
# /data/datasets/dataset_kitti/02/lidar/000468.bin
# /data/datasets/dataset_kitti/02/lidar/000469.bin
# /data/datasets/dataset_kitti/02/lidar/000470.bin
# /data/datasets/dataset_kitti/02/lidar/000471.bin
# /data/datasets/dataset_kitti/02/lidar/000472.bin
# /data/datasets/dataset_kitti/02/lidar/000473.bin
# /data/datasets/dataset_kitti/02/lidar/000474.bin
# /data/datasets/dataset_kitti/02/lidar/000475.bin
# /data/datasets/dataset_kitti/02/lidar/000476.bin
# /data/datasets/dataset_kitti/02/lidar/000477.bin
# /data/datasets/dataset_kitti/02/lidar/000478.bin
# /data/datasets/dataset_kitti/02/lidar/000479.bin
# /data/datasets/dataset_kitti/02/lidar/000480.bin
# /data/datasets/dataset_kitti/02/lidar/000481.bin
# /data/datasets/dataset_kitti/02/lidar/000482.bin
# /data/datasets/dataset_kitti/02/lidar/000483.bin
# /data/datasets/dataset_kitti/02/lidar/000484.bin
# /data/datasets/dataset_kitti/02/lidar/000485.bin
# /data/datasets/dataset_kitti/02/lidar/000486.bin
# /data/datasets/dataset_kitti/02/lidar/000487.bin
# /data/datasets/dataset_kitti/02/lidar/000488.bin
# /data/datasets/dataset_kitti/02/lidar/000489.bin
# /data/datasets/dataset_kitti/02/lidar/000490.bin
# /data/datasets/dataset_kitti/02/lidar/000491.bin
# /data/datasets/dataset_kitti/02/lidar/000492.bin
# /data/datasets/dataset_kitti/02/lidar/000493.bin
# /data/datasets/dataset_kitti/02/lidar/000494.bin
# /data/datasets/dataset_kitti/02/lidar/000495.bin
# /data/datasets/dataset_kitti/02/lidar/000496.bin
# /data/datasets/dataset_kitti/02/lidar/000497.bin
# /data/datasets/dataset_kitti/02/lidar/000498.bin
# /data/datasets/dataset_kitti/02/lidar/000499.bin
# /data/datasets/dataset_kitti/02/lidar/000500.bin
# /data/datasets/dataset_kitti/02/lidar/000501.bin
# /data/datasets/dataset_kitti/02/lidar/000502.bin
# /data/datasets/dataset_kitti/02/lidar/000503.bin
# /data/datasets/dataset_kitti/02/lidar/000504.bin
# /data/datasets/dataset_kitti/02/lidar/000505.bin
# /data/datasets/dataset_kitti/02/lidar/000506.bin
# /data/datasets/dataset_kitti/02/lidar/000507.bin
# /data/datasets/dataset_kitti/02/lidar/000508.bin
# /data/datasets/dataset_kitti/02/lidar/000509.bin
# /data/datasets/dataset_kitti/02/lidar/000510.bin
# /data/datasets/dataset_kitti/02/lidar/000511.bin
# /data/datasets/dataset_kitti/02/lidar/000512.bin
# /data/datasets/dataset_kitti/02/lidar/000513.bin
# /data/datasets/dataset_kitti/02/lidar/000514.bin
# /data/datasets/dataset_kitti/02/lidar/000515.bin
# /data/datasets/dataset_kitti/02/lidar/000516.bin
# /data/datasets/dataset_kitti/02/lidar/000517.bin
# /data/datasets/dataset_kitti/02/lidar/000518.bin
# /data/datasets/dataset_kitti/02/lidar/000519.bin
# /data/datasets/dataset_kitti/02/lidar/000520.bin
# /data/datasets/dataset_kitti/02/lidar/000521.bin
# /data/datasets/dataset_kitti/02/lidar/000522.bin
# /data/datasets/dataset_kitti/02/lidar/000523.bin
# /data/datasets/dataset_kitti/02/lidar/000524.bin
# /data/datasets/dataset_kitti/02/lidar/000525.bin
# /data/datasets/dataset_kitti/02/lidar/000526.bin
# /data/datasets/dataset_kitti/02/lidar/000527.bin
# /data/datasets/dataset_kitti/02/lidar/000528.bin
# /data/datasets/dataset_kitti/02/lidar/000529.bin
# /data/datasets/dataset_kitti/02/lidar/000530.bin
# /data/datasets/dataset_kitti/02/lidar/000531.bin
# /data/datasets/dataset_kitti/02/lidar/000532.bin
# /data/datasets/dataset_kitti/02/lidar/000533.bin
# /data/datasets/dataset_kitti/02/lidar/000534.bin
# /data/datasets/dataset_kitti/02/lidar/000535.bin
# /data/datasets/dataset_kitti/02/lidar/000536.bin
# /data/datasets/dataset_kitti/02/lidar/000537.bin
# /data/datasets/dataset_kitti/02/lidar/000538.bin
# /data/datasets/dataset_kitti/02/lidar/000539.bin
# /data/datasets/dataset_kitti/02/lidar/000540.bin
# /data/datasets/dataset_kitti/02/lidar/000541.bin
# /data/datasets/dataset_kitti/02/lidar/000542.bin
# /data/datasets/dataset_kitti/02/lidar/000543.bin
# /data/datasets/dataset_kitti/02/lidar/000544.bin
# /data/datasets/dataset_kitti/02/lidar/000545.bin
# /data/datasets/dataset_kitti/02/lidar/000546.bin
# /data/datasets/dataset_kitti/02/lidar/000547.bin
# /data/datasets/dataset_kitti/02/lidar/000548.bin
# /data/datasets/dataset_kitti/02/lidar/000549.bin
# /data/datasets/dataset_kitti/02/lidar/000550.bin
# /data/datasets/dataset_kitti/02/lidar/000551.bin
# /data/datasets/dataset_kitti/02/lidar/000552.bin
# /data/datasets/dataset_kitti/02/lidar/000553.bin
# /data/datasets/dataset_kitti/02/lidar/000554.bin
# /data/datasets/dataset_kitti/02/lidar/000555.bin
# /data/datasets/dataset_kitti/02/lidar/000556.bin
# /data/datasets/dataset_kitti/02/lidar/000557.bin
# /data/datasets/dataset_kitti/02/lidar/000558.bin
# /data/datasets/dataset_kitti/02/lidar/000559.bin
# /data/datasets/dataset_kitti/02/lidar/000560.bin
# /data/datasets/dataset_kitti/02/lidar/000561.bin
# /data/datasets/dataset_kitti/02/lidar/000562.bin
# /data/datasets/dataset_kitti/02/lidar/000563.bin
# /data/datasets/dataset_kitti/02/lidar/000564.bin
# /data/datasets/dataset_kitti/02/lidar/000565.bin
# /data/datasets/dataset_kitti/02/lidar/000566.bin
# /data/datasets/dataset_kitti/02/lidar/000567.bin
# /data/datasets/dataset_kitti/02/lidar/000568.bin
# /data/datasets/dataset_kitti/02/lidar/000569.bin
# /data/datasets/dataset_kitti/02/lidar/000570.bin
# /data/datasets/dataset_kitti/02/lidar/000571.bin
# /data/datasets/dataset_kitti/02/lidar/000572.bin
# /data/datasets/dataset_kitti/02/lidar/000573.bin
# /data/datasets/dataset_kitti/02/lidar/000574.bin
# /data/datasets/dataset_kitti/02/lidar/000575.bin
# /data/datasets/dataset_kitti/02/lidar/000576.bin
# /data/datasets/dataset_kitti/02/lidar/000577.bin
# /data/datasets/dataset_kitti/02/lidar/000578.bin
# /data/datasets/dataset_kitti/02/lidar/000579.bin
# /data/datasets/dataset_kitti/02/lidar/000580.bin
# /data/datasets/dataset_kitti/02/lidar/000581.bin
# /data/datasets/dataset_kitti/02/lidar/000582.bin
# /data/datasets/dataset_kitti/02/lidar/000583.bin
# /data/datasets/dataset_kitti/02/lidar/000584.bin
# /data/datasets/dataset_kitti/02/lidar/000585.bin
# /data/datasets/dataset_kitti/02/lidar/000586.bin
# /data/datasets/dataset_kitti/02/lidar/000587.bin
# /data/datasets/dataset_kitti/02/lidar/000588.bin
# /data/datasets/dataset_kitti/02/lidar/000589.bin
# /data/datasets/dataset_kitti/02/lidar/000590.bin
# /data/datasets/dataset_kitti/02/lidar/000591.bin
# /data/datasets/dataset_kitti/02/lidar/000592.bin
# /data/datasets/dataset_kitti/02/lidar/000593.bin
# /data/datasets/dataset_kitti/02/lidar/000594.bin
# /data/datasets/dataset_kitti/02/lidar/000595.bin
# /data/datasets/dataset_kitti/02/lidar/000596.bin
# /data/datasets/dataset_kitti/02/lidar/000597.bin
# /data/datasets/dataset_kitti/02/lidar/000598.bin
# /data/datasets/dataset_kitti/02/lidar/000599.bin
# /data/datasets/dataset_kitti/02/lidar/000600.bin
# /data/datasets/dataset_kitti/02/lidar/000601.bin
# /data/datasets/dataset_kitti/02/lidar/000602.bin
# /data/datasets/dataset_kitti/02/lidar/000603.bin
# /data/datasets/dataset_kitti/02/lidar/000604.bin
# /data/datasets/dataset_kitti/02/lidar/000605.bin
# /data/datasets/dataset_kitti/02/lidar/000606.bin
# /data/datasets/dataset_kitti/02/lidar/000607.bin
# /data/datasets/dataset_kitti/02/lidar/000608.bin
# /data/datasets/dataset_kitti/02/lidar/000609.bin
# /data/datasets/dataset_kitti/02/lidar/000610.bin
# /data/datasets/dataset_kitti/02/lidar/000611.bin
# /data/datasets/dataset_kitti/02/lidar/000612.bin
# /data/datasets/dataset_kitti/02/lidar/000613.bin
# /data/datasets/dataset_kitti/02/lidar/000614.bin
# /data/datasets/dataset_kitti/02/lidar/000615.bin
# /data/datasets/dataset_kitti/02/lidar/000616.bin
# /data/datasets/dataset_kitti/02/lidar/000617.bin
# /data/datasets/dataset_kitti/02/lidar/000618.bin
# /data/datasets/dataset_kitti/02/lidar/000619.bin
# /data/datasets/dataset_kitti/02/lidar/000620.bin
# /data/datasets/dataset_kitti/02/lidar/000621.bin
# /data/datasets/dataset_kitti/02/lidar/000622.bin
# /data/datasets/dataset_kitti/02/lidar/000623.bin
# /data/datasets/dataset_kitti/02/lidar/000624.bin
# /data/datasets/dataset_kitti/02/lidar/000625.bin
# /data/datasets/dataset_kitti/02/lidar/000626.bin
# /data/datasets/dataset_kitti/02/lidar/000627.bin
# /data/datasets/dataset_kitti/02/lidar/000628.bin
# /data/datasets/dataset_kitti/02/lidar/000629.bin
# /data/datasets/dataset_kitti/02/lidar/000630.bin
# /data/datasets/dataset_kitti/02/lidar/000631.bin
# /data/datasets/dataset_kitti/02/lidar/000632.bin
# /data/datasets/dataset_kitti/02/lidar/000633.bin
# /data/datasets/dataset_kitti/02/lidar/000634.bin
# /data/datasets/dataset_kitti/02/lidar/000635.bin
# /data/datasets/dataset_kitti/02/lidar/000636.bin
# /data/datasets/dataset_kitti/02/lidar/000637.bin
# /data/datasets/dataset_kitti/02/lidar/000638.bin
# /data/datasets/dataset_kitti/02/lidar/000639.bin
# /data/datasets/dataset_kitti/02/lidar/000640.bin
# /data/datasets/dataset_kitti/02/lidar/000641.bin
# /data/datasets/dataset_kitti/02/lidar/000642.bin
# /data/datasets/dataset_kitti/02/lidar/000643.bin
# /data/datasets/dataset_kitti/02/lidar/000644.bin
# /data/datasets/dataset_kitti/02/lidar/000645.bin
# /data/datasets/dataset_kitti/02/lidar/000646.bin
# /data/datasets/dataset_kitti/02/lidar/000647.bin
# /data/datasets/dataset_kitti/02/lidar/000648.bin
# /data/datasets/dataset_kitti/02/lidar/000649.bin
# /data/datasets/dataset_kitti/02/lidar/000650.bin
# /data/datasets/dataset_kitti/02/lidar/000651.bin
# /data/datasets/dataset_kitti/02/lidar/000652.bin
# /data/datasets/dataset_kitti/02/lidar/000653.bin
# /data/datasets/dataset_kitti/02/lidar/000654.bin
# /data/datasets/dataset_kitti/02/lidar/000655.bin
# /data/datasets/dataset_kitti/02/lidar/000656.bin
# /data/datasets/dataset_kitti/02/lidar/000657.bin
# /data/datasets/dataset_kitti/02/lidar/000658.bin
# /data/datasets/dataset_kitti/02/lidar/000659.bin
# /data/datasets/dataset_kitti/02/lidar/000660.bin
# /data/datasets/dataset_kitti/02/lidar/000661.bin
# /data/datasets/dataset_kitti/02/lidar/000662.bin
# /data/datasets/dataset_kitti/02/lidar/000663.bin
# /data/datasets/dataset_kitti/02/lidar/000664.bin
# /data/datasets/dataset_kitti/02/lidar/000665.bin
# /data/datasets/dataset_kitti/02/lidar/000666.bin
# /data/datasets/dataset_kitti/02/lidar/000667.bin
# /data/datasets/dataset_kitti/02/lidar/000668.bin
# /data/datasets/dataset_kitti/02/lidar/000669.bin
# /data/datasets/dataset_kitti/02/lidar/000670.bin
# /data/datasets/dataset_kitti/02/lidar/000671.bin
# /data/datasets/dataset_kitti/02/lidar/000672.bin
# /data/datasets/dataset_kitti/02/lidar/000673.bin
# /data/datasets/dataset_kitti/02/lidar/000674.bin
# /data/datasets/dataset_kitti/02/lidar/000675.bin
# /data/datasets/dataset_kitti/02/lidar/000676.bin
# /data/datasets/dataset_kitti/02/lidar/000677.bin
# /data/datasets/dataset_kitti/02/lidar/000678.bin
# /data/datasets/dataset_kitti/02/lidar/000679.bin
# /data/datasets/dataset_kitti/02/lidar/000680.bin
# /data/datasets/dataset_kitti/02/lidar/000681.bin
# /data/datasets/dataset_kitti/02/lidar/000682.bin
# /data/datasets/dataset_kitti/02/lidar/000683.bin
# /data/datasets/dataset_kitti/02/lidar/000684.bin
# /data/datasets/dataset_kitti/02/lidar/000685.bin
# /data/datasets/dataset_kitti/02/lidar/000686.bin
# /data/datasets/dataset_kitti/02/lidar/000687.bin
# /data/datasets/dataset_kitti/02/lidar/000688.bin
# /data/datasets/dataset_kitti/02/lidar/000689.bin
# /data/datasets/dataset_kitti/02/lidar/000690.bin
# /data/datasets/dataset_kitti/02/lidar/000691.bin
# /data/datasets/dataset_kitti/02/lidar/000692.bin
# /data/datasets/dataset_kitti/02/lidar/000693.bin
# /data/datasets/dataset_kitti/02/lidar/000694.bin
# /data/datasets/dataset_kitti/02/lidar/000695.bin
# /data/datasets/dataset_kitti/02/lidar/000696.bin
# /data/datasets/dataset_kitti/02/lidar/000697.bin
# /data/datasets/dataset_kitti/02/lidar/000698.bin
# /data/datasets/dataset_kitti/02/lidar/000699.bin
# /data/datasets/dataset_kitti/02/lidar/000700.bin
# /data/datasets/dataset_kitti/02/lidar/000701.bin
# /data/datasets/dataset_kitti/02/lidar/000702.bin
# /data/datasets/dataset_kitti/02/lidar/000703.bin
# /data/datasets/dataset_kitti/02/lidar/000704.bin
# /data/datasets/dataset_kitti/02/lidar/000705.bin
# /data/datasets/dataset_kitti/02/lidar/000706.bin
# /data/datasets/dataset_kitti/02/lidar/000707.bin
# /data/datasets/dataset_kitti/02/lidar/000708.bin
# /data/datasets/dataset_kitti/02/lidar/000709.bin
# /data/datasets/dataset_kitti/02/lidar/000710.bin
# /data/datasets/dataset_kitti/02/lidar/000711.bin
# /data/datasets/dataset_kitti/02/lidar/000712.bin
# /data/datasets/dataset_kitti/02/lidar/000713.bin
# /data/datasets/dataset_kitti/02/lidar/000714.bin
# /data/datasets/dataset_kitti/02/lidar/000715.bin
# /data/datasets/dataset_kitti/02/lidar/000716.bin
# /data/datasets/dataset_kitti/02/lidar/000717.bin
# /data/datasets/dataset_kitti/02/lidar/000718.bin
# /data/datasets/dataset_kitti/02/lidar/000719.bin
# /data/datasets/dataset_kitti/02/lidar/000720.bin
# /data/datasets/dataset_kitti/02/lidar/000721.bin
# /data/datasets/dataset_kitti/02/lidar/000722.bin
# /data/datasets/dataset_kitti/02/lidar/000723.bin
# /data/datasets/dataset_kitti/02/lidar/000724.bin
# /data/datasets/dataset_kitti/02/lidar/000725.bin
# /data/datasets/dataset_kitti/02/lidar/000726.bin
# /data/datasets/dataset_kitti/02/lidar/000727.bin
# /data/datasets/dataset_kitti/02/lidar/000728.bin
# /data/datasets/dataset_kitti/02/lidar/000729.bin
# /data/datasets/dataset_kitti/02/lidar/000730.bin
# /data/datasets/dataset_kitti/02/lidar/000731.bin
# /data/datasets/dataset_kitti/02/lidar/000732.bin
# /data/datasets/dataset_kitti/02/lidar/000733.bin
# /data/datasets/dataset_kitti/02/lidar/000734.bin
# /data/datasets/dataset_kitti/02/lidar/000735.bin
# /data/datasets/dataset_kitti/02/lidar/000736.bin
# /data/datasets/dataset_kitti/02/lidar/000737.bin
# /data/datasets/dataset_kitti/02/lidar/000738.bin
# /data/datasets/dataset_kitti/02/lidar/000739.bin
# /data/datasets/dataset_kitti/02/lidar/000740.bin
# /data/datasets/dataset_kitti/02/lidar/000741.bin
# /data/datasets/dataset_kitti/02/lidar/000742.bin
# /data/datasets/dataset_kitti/02/lidar/000743.bin
# /data/datasets/dataset_kitti/02/lidar/000744.bin
# /data/datasets/dataset_kitti/02/lidar/000745.bin
# /data/datasets/dataset_kitti/02/lidar/000746.bin
# /data/datasets/dataset_kitti/02/lidar/000747.bin
# /data/datasets/dataset_kitti/02/lidar/000748.bin
# /data/datasets/dataset_kitti/02/lidar/000749.bin
# /data/datasets/dataset_kitti/02/lidar/000750.bin
# /data/datasets/dataset_kitti/02/lidar/000751.bin
# /data/datasets/dataset_kitti/02/lidar/000752.bin
# /data/datasets/dataset_kitti/02/lidar/000753.bin
# /data/datasets/dataset_kitti/02/lidar/000754.bin
# /data/datasets/dataset_kitti/02/lidar/000755.bin
# /data/datasets/dataset_kitti/02/lidar/000756.bin
# /data/datasets/dataset_kitti/02/lidar/000757.bin
# /data/datasets/dataset_kitti/02/lidar/000758.bin
# /data/datasets/dataset_kitti/02/lidar/000759.bin
# /data/datasets/dataset_kitti/02/lidar/000760.bin
# /data/datasets/dataset_kitti/02/lidar/000761.bin
# /data/datasets/dataset_kitti/02/lidar/000762.bin
# /data/datasets/dataset_kitti/02/lidar/000763.bin
# /data/datasets/dataset_kitti/02/lidar/000764.bin
# /data/datasets/dataset_kitti/02/lidar/000765.bin
# /data/datasets/dataset_kitti/02/lidar/000766.bin
# /data/datasets/dataset_kitti/02/lidar/000767.bin
# /data/datasets/dataset_kitti/02/lidar/000768.bin
# /data/datasets/dataset_kitti/02/lidar/000769.bin
# /data/datasets/dataset_kitti/02/lidar/000770.bin
# /data/datasets/dataset_kitti/02/lidar/000771.bin
# /data/datasets/dataset_kitti/02/lidar/000772.bin
# /data/datasets/dataset_kitti/02/lidar/000773.bin
# /data/datasets/dataset_kitti/02/lidar/000774.bin
# /data/datasets/dataset_kitti/02/lidar/000775.bin
# /data/datasets/dataset_kitti/02/lidar/000776.bin
# /data/datasets/dataset_kitti/02/lidar/000777.bin
# /data/datasets/dataset_kitti/02/lidar/000778.bin
# /data/datasets/dataset_kitti/02/lidar/000779.bin
# /data/datasets/dataset_kitti/02/lidar/000780.bin
# /data/datasets/dataset_kitti/02/lidar/000781.bin
# /data/datasets/dataset_kitti/02/lidar/000782.bin
# /data/datasets/dataset_kitti/02/lidar/000783.bin
# /data/datasets/dataset_kitti/02/lidar/000784.bin
# /data/datasets/dataset_kitti/02/lidar/000785.bin
# /data/datasets/dataset_kitti/02/lidar/000786.bin
# /data/datasets/dataset_kitti/02/lidar/000787.bin
# /data/datasets/dataset_kitti/02/lidar/000788.bin
# /data/datasets/dataset_kitti/02/lidar/000789.bin
# /data/datasets/dataset_kitti/02/lidar/000790.bin
# /data/datasets/dataset_kitti/02/lidar/000791.bin
# /data/datasets/dataset_kitti/02/lidar/000792.bin
# /data/datasets/dataset_kitti/02/lidar/000793.bin
# /data/datasets/dataset_kitti/02/lidar/000794.bin
# /data/datasets/dataset_kitti/02/lidar/000795.bin
# /data/datasets/dataset_kitti/02/lidar/000796.bin
# /data/datasets/dataset_kitti/02/lidar/000797.bin
# /data/datasets/dataset_kitti/02/lidar/000798.bin
# /data/datasets/dataset_kitti/02/lidar/000799.bin
# /data/datasets/dataset_kitti/02/lidar/000800.bin
# /data/datasets/dataset_kitti/02/lidar/000801.bin
# /data/datasets/dataset_kitti/02/lidar/000802.bin
# /data/datasets/dataset_kitti/02/lidar/000803.bin
# /data/datasets/dataset_kitti/02/lidar/000804.bin
# /data/datasets/dataset_kitti/02/lidar/000805.bin
# /data/datasets/dataset_kitti/02/lidar/000806.bin
# /data/datasets/dataset_kitti/02/lidar/000807.bin
# /data/datasets/dataset_kitti/02/lidar/000808.bin
# /data/datasets/dataset_kitti/02/lidar/000809.bin
# /data/datasets/dataset_kitti/02/lidar/000810.bin
# /data/datasets/dataset_kitti/02/lidar/000811.bin
# /data/datasets/dataset_kitti/02/lidar/000812.bin
# /data/datasets/dataset_kitti/02/lidar/000813.bin
# /data/datasets/dataset_kitti/02/lidar/000814.bin
# /data/datasets/dataset_kitti/02/lidar/000815.bin
# /data/datasets/dataset_kitti/02/lidar/000816.bin
# /data/datasets/dataset_kitti/02/lidar/000817.bin
# /data/datasets/dataset_kitti/02/lidar/000818.bin
# /data/datasets/dataset_kitti/02/lidar/000819.bin
# /data/datasets/dataset_kitti/02/lidar/000820.bin
# /data/datasets/dataset_kitti/02/lidar/000821.bin
# /data/datasets/dataset_kitti/02/lidar/000822.bin
# /data/datasets/dataset_kitti/02/lidar/000823.bin
# /data/datasets/dataset_kitti/02/lidar/000824.bin
# /data/datasets/dataset_kitti/02/lidar/000825.bin
# /data/datasets/dataset_kitti/02/lidar/000826.bin
# /data/datasets/dataset_kitti/02/lidar/000827.bin
# /data/datasets/dataset_kitti/02/lidar/000828.bin
# /data/datasets/dataset_kitti/02/lidar/000829.bin
# /data/datasets/dataset_kitti/02/lidar/000830.bin
# /data/datasets/dataset_kitti/02/lidar/000831.bin
# /data/datasets/dataset_kitti/02/lidar/000832.bin
# /data/datasets/dataset_kitti/02/lidar/000833.bin
# /data/datasets/dataset_kitti/02/lidar/000834.bin
# /data/datasets/dataset_kitti/02/lidar/000835.bin
# /data/datasets/dataset_kitti/02/lidar/000836.bin
# /data/datasets/dataset_kitti/02/lidar/000837.bin
# /data/datasets/dataset_kitti/02/lidar/000838.bin
# /data/datasets/dataset_kitti/02/lidar/000839.bin
# /data/datasets/dataset_kitti/02/lidar/000840.bin
# /data/datasets/dataset_kitti/02/lidar/000841.bin
# /data/datasets/dataset_kitti/02/lidar/000842.bin
# /data/datasets/dataset_kitti/02/lidar/000843.bin
# /data/datasets/dataset_kitti/02/lidar/000844.bin
# /data/datasets/dataset_kitti/02/lidar/000845.bin
# /data/datasets/dataset_kitti/02/lidar/000846.bin
# /data/datasets/dataset_kitti/02/lidar/000847.bin
# /data/datasets/dataset_kitti/02/lidar/000848.bin
# /data/datasets/dataset_kitti/02/lidar/000849.bin
# /data/datasets/dataset_kitti/02/lidar/000850.bin
# /data/datasets/dataset_kitti/02/lidar/000851.bin
# /data/datasets/dataset_kitti/02/lidar/000852.bin
# /data/datasets/dataset_kitti/02/lidar/000853.bin
# /data/datasets/dataset_kitti/02/lidar/000854.bin
# /data/datasets/dataset_kitti/02/lidar/000855.bin
# /data/datasets/dataset_kitti/02/lidar/000856.bin
# /data/datasets/dataset_kitti/02/lidar/000857.bin
# /data/datasets/dataset_kitti/02/lidar/000858.bin
# /data/datasets/dataset_kitti/02/lidar/000859.bin
# /data/datasets/dataset_kitti/02/lidar/000860.bin
# /data/datasets/dataset_kitti/02/lidar/000861.bin
# /data/datasets/dataset_kitti/02/lidar/000862.bin
# /data/datasets/dataset_kitti/02/lidar/000863.bin
# /data/datasets/dataset_kitti/02/lidar/000864.bin
# /data/datasets/dataset_kitti/02/lidar/000865.bin
# /data/datasets/dataset_kitti/02/lidar/000866.bin
# /data/datasets/dataset_kitti/02/lidar/000867.bin
# /data/datasets/dataset_kitti/02/lidar/000868.bin
# /data/datasets/dataset_kitti/02/lidar/000869.bin
# /data/datasets/dataset_kitti/02/lidar/000870.bin
# /data/datasets/dataset_kitti/02/lidar/000871.bin
# /data/datasets/dataset_kitti/02/lidar/000872.bin
# /data/datasets/dataset_kitti/02/lidar/000873.bin
# /data/datasets/dataset_kitti/02/lidar/000874.bin
# /data/datasets/dataset_kitti/02/lidar/000875.bin
# /data/datasets/dataset_kitti/02/lidar/000876.bin
# /data/datasets/dataset_kitti/02/lidar/000877.bin
# /data/datasets/dataset_kitti/02/lidar/000878.bin
# /data/datasets/dataset_kitti/02/lidar/000879.bin
# /data/datasets/dataset_kitti/02/lidar/000880.bin
# /data/datasets/dataset_kitti/02/lidar/000881.bin
# /data/datasets/dataset_kitti/02/lidar/000882.bin
# /data/datasets/dataset_kitti/02/lidar/000883.bin
# /data/datasets/dataset_kitti/02/lidar/000884.bin
# /data/datasets/dataset_kitti/02/lidar/000885.bin
# /data/datasets/dataset_kitti/02/lidar/000886.bin
# /data/datasets/dataset_kitti/02/lidar/000887.bin
# /data/datasets/dataset_kitti/02/lidar/000888.bin
# /data/datasets/dataset_kitti/02/lidar/000889.bin
# /data/datasets/dataset_kitti/02/lidar/000890.bin
# /data/datasets/dataset_kitti/02/lidar/000891.bin
# /data/datasets/dataset_kitti/02/lidar/000892.bin
# /data/datasets/dataset_kitti/02/lidar/000893.bin
# /data/datasets/dataset_kitti/02/lidar/000894.bin
# /data/datasets/dataset_kitti/02/lidar/000895.bin
# /data/datasets/dataset_kitti/02/lidar/000896.bin
# /data/datasets/dataset_kitti/02/lidar/000897.bin
# /data/datasets/dataset_kitti/02/lidar/000898.bin
# /data/datasets/dataset_kitti/02/lidar/000899.bin
# /data/datasets/dataset_kitti/02/lidar/000900.bin
# /data/datasets/dataset_kitti/02/lidar/000901.bin
# /data/datasets/dataset_kitti/02/lidar/000902.bin
# /data/datasets/dataset_kitti/02/lidar/000903.bin
# /data/datasets/dataset_kitti/02/lidar/000904.bin
# /data/datasets/dataset_kitti/02/lidar/000905.bin
# /data/datasets/dataset_kitti/02/lidar/000906.bin
# /data/datasets/dataset_kitti/02/lidar/000907.bin
# /data/datasets/dataset_kitti/02/lidar/000908.bin
# /data/datasets/dataset_kitti/02/lidar/000909.bin
# /data/datasets/dataset_kitti/02/lidar/000910.bin
# /data/datasets/dataset_kitti/02/lidar/000911.bin
# /data/datasets/dataset_kitti/02/lidar/000912.bin
# /data/datasets/dataset_kitti/02/lidar/000913.bin
# /data/datasets/dataset_kitti/02/lidar/000914.bin
# /data/datasets/dataset_kitti/02/lidar/000915.bin
# /data/datasets/dataset_kitti/02/lidar/000916.bin
# /data/datasets/dataset_kitti/02/lidar/000917.bin
# /data/datasets/dataset_kitti/02/lidar/000918.bin
# /data/datasets/dataset_kitti/02/lidar/000919.bin
# /data/datasets/dataset_kitti/02/lidar/000920.bin
# /data/datasets/dataset_kitti/02/lidar/000921.bin
# /data/datasets/dataset_kitti/02/lidar/000922.bin
# /data/datasets/dataset_kitti/02/lidar/000923.bin
# /data/datasets/dataset_kitti/02/lidar/000924.bin
# /data/datasets/dataset_kitti/02/lidar/000925.bin
# /data/datasets/dataset_kitti/02/lidar/000926.bin
# /data/datasets/dataset_kitti/02/lidar/000927.bin
# /data/datasets/dataset_kitti/02/lidar/000928.bin
# /data/datasets/dataset_kitti/02/lidar/000929.bin
# /data/datasets/dataset_kitti/02/lidar/000930.bin
# /data/datasets/dataset_kitti/02/lidar/000931.bin
# /data/datasets/dataset_kitti/02/lidar/000932.bin
# /data/datasets/dataset_kitti/02/lidar/000933.bin
# /data/datasets/dataset_kitti/02/lidar/000934.bin
# /data/datasets/dataset_kitti/02/lidar/000935.bin
# /data/datasets/dataset_kitti/02/lidar/000936.bin
# /data/datasets/dataset_kitti/02/lidar/000937.bin
# /data/datasets/dataset_kitti/02/lidar/000938.bin
# /data/datasets/dataset_kitti/02/lidar/000939.bin
# /data/datasets/dataset_kitti/02/lidar/000940.bin
# /data/datasets/dataset_kitti/02/lidar/000941.bin
# /data/datasets/dataset_kitti/02/lidar/000942.bin
# /data/datasets/dataset_kitti/02/lidar/000943.bin
# /data/datasets/dataset_kitti/02/lidar/000944.bin
# /data/datasets/dataset_kitti/02/lidar/000945.bin
# /data/datasets/dataset_kitti/02/lidar/000946.bin
# /data/datasets/dataset_kitti/02/lidar/000947.bin
# /data/datasets/dataset_kitti/02/lidar/000948.bin
# /data/datasets/dataset_kitti/02/lidar/000949.bin
# /data/datasets/dataset_kitti/02/lidar/000950.bin
# /data/datasets/dataset_kitti/02/lidar/000951.bin
# /data/datasets/dataset_kitti/02/lidar/000952.bin
# /data/datasets/dataset_kitti/02/lidar/000953.bin
# /data/datasets/dataset_kitti/02/lidar/000954.bin
# /data/datasets/dataset_kitti/02/lidar/000955.bin
# /data/datasets/dataset_kitti/02/lidar/000956.bin
# /data/datasets/dataset_kitti/02/lidar/000957.bin
# /data/datasets/dataset_kitti/02/lidar/000958.bin
# /data/datasets/dataset_kitti/02/lidar/000959.bin
# /data/datasets/dataset_kitti/02/lidar/000960.bin
# /data/datasets/dataset_kitti/02/lidar/000961.bin
# /data/datasets/dataset_kitti/02/lidar/000962.bin
# /data/datasets/dataset_kitti/02/lidar/000963.bin
# /data/datasets/dataset_kitti/02/lidar/000964.bin
# /data/datasets/dataset_kitti/02/lidar/000965.bin
# /data/datasets/dataset_kitti/02/lidar/000966.bin
# /data/datasets/dataset_kitti/02/lidar/000967.bin
# /data/datasets/dataset_kitti/02/lidar/000968.bin
# /data/datasets/dataset_kitti/02/lidar/000969.bin
# /data/datasets/dataset_kitti/02/lidar/000970.bin
# /data/datasets/dataset_kitti/02/lidar/000971.bin
# /data/datasets/dataset_kitti/02/lidar/000972.bin
# /data/datasets/dataset_kitti/02/lidar/000973.bin
# /data/datasets/dataset_kitti/02/lidar/000974.bin
# /data/datasets/dataset_kitti/02/lidar/000975.bin
# ...
# /data/datasets/dataset_kitti/10/lidar/000876.bin
# /data/datasets/dataset_kitti/10/lidar/000877.bin
# /data/datasets/dataset_kitti/10/lidar/000878.bin
# /data/datasets/dataset_kitti/10/lidar/000879.bin
# /data/datasets/dataset_kitti/10/lidar/000880.bin
# /data/datasets/dataset_kitti/10/lidar/000881.bin
# /data/datasets/dataset_kitti/10/lidar/000882.bin
# /data/datasets/dataset_kitti/10/lidar/000883.bin
# /data/datasets/dataset_kitti/10/lidar/000884.bin
# /data/datasets/dataset_kitti/10/lidar/000885.bin
# /data/datasets/dataset_kitti/10/lidar/000886.bin
# /data/datasets/dataset_kitti/10/lidar/000887.bin
# /data/datasets/dataset_kitti/10/lidar/000888.bin
# /data/datasets/dataset_kitti/10/lidar/000889.bin
# /data/datasets/dataset_kitti/10/lidar/000890.bin
# /data/datasets/dataset_kitti/10/lidar/000891.bin
# /data/datasets/dataset_kitti/10/lidar/000892.bin
# /data/datasets/dataset_kitti/10/lidar/000893.bin
# /data/datasets/dataset_kitti/10/lidar/000894.bin
# /data/datasets/dataset_kitti/10/lidar/000895.bin
# /data/datasets/dataset_kitti/10/lidar/000896.bin
# /data/datasets/dataset_kitti/10/lidar/000897.bin
# /data/datasets/dataset_kitti/10/lidar/000898.bin
# /data/datasets/dataset_kitti/10/lidar/000899.bin
# /data/datasets/dataset_kitti/10/lidar/000900.bin
# /data/datasets/dataset_kitti/10/lidar/000901.bin
# /data/datasets/dataset_kitti/10/lidar/000902.bin
# /data/datasets/dataset_kitti/10/lidar/000903.bin
# /data/datasets/dataset_kitti/10/lidar/000904.bin
# /data/datasets/dataset_kitti/10/lidar/000905.bin
# /data/datasets/dataset_kitti/10/lidar/000906.bin
# /data/datasets/dataset_kitti/10/lidar/000907.bin
# /data/datasets/dataset_kitti/10/lidar/000908.bin
# /data/datasets/dataset_kitti/10/lidar/000909.bin
# /data/datasets/dataset_kitti/10/lidar/000910.bin
# /data/datasets/dataset_kitti/10/lidar/000911.bin
# /data/datasets/dataset_kitti/10/lidar/000912.bin
# /data/datasets/dataset_kitti/10/lidar/000913.bin
# /data/datasets/dataset_kitti/10/lidar/000914.bin
# /data/datasets/dataset_kitti/10/lidar/000915.bin
# /data/datasets/dataset_kitti/10/lidar/000916.bin
# /data/datasets/dataset_kitti/10/lidar/000917.bin
# /data/datasets/dataset_kitti/10/lidar/000918.bin
# /data/datasets/dataset_kitti/10/lidar/000919.bin
# /data/datasets/dataset_kitti/10/lidar/000920.bin
# /data/datasets/dataset_kitti/10/lidar/000921.bin
# /data/datasets/dataset_kitti/10/lidar/000922.bin
# /data/datasets/dataset_kitti/10/lidar/000923.bin
# /data/datasets/dataset_kitti/10/lidar/000924.bin
# /data/datasets/dataset_kitti/10/lidar/000925.bin
# /data/datasets/dataset_kitti/10/lidar/000926.bin
# /data/datasets/dataset_kitti/10/lidar/000927.bin
# /data/datasets/dataset_kitti/10/lidar/000928.bin
# /data/datasets/dataset_kitti/10/lidar/000929.bin
# /data/datasets/dataset_kitti/10/lidar/000930.bin
# /data/datasets/dataset_kitti/10/lidar/000931.bin
# /data/datasets/dataset_kitti/10/lidar/000932.bin
# /data/datasets/dataset_kitti/10/lidar/000933.bin
# /data/datasets/dataset_kitti/10/lidar/000934.bin
# /data/datasets/dataset_kitti/10/lidar/000935.bin
# /data/datasets/dataset_kitti/10/lidar/000936.bin
# /data/datasets/dataset_kitti/10/lidar/000937.bin
# /data/datasets/dataset_kitti/10/lidar/000938.bin
# /data/datasets/dataset_kitti/10/lidar/000939.bin
# /data/datasets/dataset_kitti/10/lidar/000940.bin
# /data/datasets/dataset_kitti/10/lidar/000941.bin
# /data/datasets/dataset_kitti/10/lidar/000942.bin
# /data/datasets/dataset_kitti/10/lidar/000943.bin
# /data/datasets/dataset_kitti/10/lidar/000944.bin
# /data/datasets/dataset_kitti/10/lidar/000945.bin
# /data/datasets/dataset_kitti/10/lidar/000946.bin
# /data/datasets/dataset_kitti/10/lidar/000947.bin
# /data/datasets/dataset_kitti/10/lidar/000948.bin
# /data/datasets/dataset_kitti/10/lidar/000949.bin
# /data/datasets/dataset_kitti/10/lidar/000950.bin
# /data/datasets/dataset_kitti/10/lidar/000951.bin
# /data/datasets/dataset_kitti/10/lidar/000952.bin
# /data/datasets/dataset_kitti/10/lidar/000953.bin
# /data/datasets/dataset_kitti/10/lidar/000954.bin
# /data/datasets/dataset_kitti/10/lidar/000955.bin
# /data/datasets/dataset_kitti/10/lidar/000956.bin
# /data/datasets/dataset_kitti/10/lidar/000957.bin
# /data/datasets/dataset_kitti/10/lidar/000958.bin
# /data/datasets/dataset_kitti/10/lidar/000959.bin
# /data/datasets/dataset_kitti/10/lidar/000960.bin
# /data/datasets/dataset_kitti/10/lidar/000961.bin
# /data/datasets/dataset_kitti/10/lidar/000962.bin
# /data/datasets/dataset_kitti/10/lidar/000963.bin
# /data/datasets/dataset_kitti/10/lidar/000964.bin
# /data/datasets/dataset_kitti/10/lidar/000965.bin
# /data/datasets/dataset_kitti/10/lidar/000966.bin
# /data/datasets/dataset_kitti/10/lidar/000967.bin
# /data/datasets/dataset_kitti/10/lidar/000968.bin
# /data/datasets/dataset_kitti/10/lidar/000969.bin
# /data/datasets/dataset_kitti/10/lidar/000970.bin
# /data/datasets/dataset_kitti/10/lidar/000971.bin
# /data/datasets/dataset_kitti/10/lidar/000972.bin
# /data/datasets/dataset_kitti/10/lidar/000973.bin
# /data/datasets/dataset_kitti/10/lidar/000974.bin
# /data/datasets/dataset_kitti/10/lidar/000975.bin
# /data/datasets/dataset_kitti/10/lidar/000976.bin
# /data/datasets/dataset_kitti/10/lidar/000977.bin
# /data/datasets/dataset_kitti/10/lidar/000978.bin
# /data/datasets/dataset_kitti/10/lidar/000979.bin
# /data/datasets/dataset_kitti/10/lidar/000980.bin
# /data/datasets/dataset_kitti/10/lidar/000981.bin
# /data/datasets/dataset_kitti/10/lidar/000982.bin
# /data/datasets/dataset_kitti/10/lidar/000983.bin
# /data/datasets/dataset_kitti/10/lidar/000984.bin
# /data/datasets/dataset_kitti/10/lidar/000985.bin
# /data/datasets/dataset_kitti/10/lidar/000986.bin
# /data/datasets/dataset_kitti/10/lidar/000987.bin
# /data/datasets/dataset_kitti/10/lidar/000988.bin
# /data/datasets/dataset_kitti/10/lidar/000989.bin
# /data/datasets/dataset_kitti/10/lidar/000990.bin
# /data/datasets/dataset_kitti/10/lidar/000991.bin
# /data/datasets/dataset_kitti/10/lidar/000992.bin
# /data/datasets/dataset_kitti/10/lidar/000993.bin
# /data/datasets/dataset_kitti/10/lidar/000994.bin
# /data/datasets/dataset_kitti/10/lidar/000995.bin
# /data/datasets/dataset_kitti/10/lidar/000996.bin
# /data/datasets/dataset_kitti/10/lidar/000997.bin
# /data/datasets/dataset_kitti/10/lidar/000998.bin
# /data/datasets/dataset_kitti/10/lidar/000999.bin
# /data/datasets/dataset_kitti/10/lidar/001000.bin
# /data/datasets/dataset_kitti/10/lidar/001001.bin
# /data/datasets/dataset_kitti/10/lidar/001002.bin
# /data/datasets/dataset_kitti/10/lidar/001003.bin
# /data/datasets/dataset_kitti/10/lidar/001004.bin
# /data/datasets/dataset_kitti/10/lidar/001005.bin
# /data/datasets/dataset_kitti/10/lidar/001006.bin
# /data/datasets/dataset_kitti/10/lidar/001007.bin
# /data/datasets/dataset_kitti/10/lidar/001008.bin
# /data/datasets/dataset_kitti/10/lidar/001009.bin
# /data/datasets/dataset_kitti/10/lidar/001010.bin
# /data/datasets/dataset_kitti/10/lidar/001011.bin
# /data/datasets/dataset_kitti/10/lidar/001012.bin
# /data/datasets/dataset_kitti/10/lidar/001013.bin
# /data/datasets/dataset_kitti/10/lidar/001014.bin
# /data/datasets/dataset_kitti/10/lidar/001015.bin
# /data/datasets/dataset_kitti/10/lidar/001016.bin
# /data/datasets/dataset_kitti/10/lidar/001017.bin
# /data/datasets/dataset_kitti/10/lidar/001018.bin
# /data/datasets/dataset_kitti/10/lidar/001019.bin
# /data/datasets/dataset_kitti/10/lidar/001020.bin
# /data/datasets/dataset_kitti/10/lidar/001021.bin
# /data/datasets/dataset_kitti/10/lidar/001022.bin
# /data/datasets/dataset_kitti/10/lidar/001023.bin
# /data/datasets/dataset_kitti/10/lidar/001024.bin
# /data/datasets/dataset_kitti/10/lidar/001025.bin
# /data/datasets/dataset_kitti/10/lidar/001026.bin
# /data/datasets/dataset_kitti/10/lidar/001027.bin
# /data/datasets/dataset_kitti/10/lidar/001028.bin
# /data/datasets/dataset_kitti/10/lidar/001029.bin
# /data/datasets/dataset_kitti/10/lidar/001030.bin
# /data/datasets/dataset_kitti/10/lidar/001031.bin
# /data/datasets/dataset_kitti/10/lidar/001032.bin
# /data/datasets/dataset_kitti/10/lidar/001033.bin
# /data/datasets/dataset_kitti/10/lidar/001034.bin
# /data/datasets/dataset_kitti/10/lidar/001035.bin
# /data/datasets/dataset_kitti/10/lidar/001036.bin
# /data/datasets/dataset_kitti/10/lidar/001037.bin
# /data/datasets/dataset_kitti/10/lidar/001038.bin
# /data/datasets/dataset_kitti/10/lidar/001039.bin
# /data/datasets/dataset_kitti/10/lidar/001040.bin
# /data/datasets/dataset_kitti/10/lidar/001041.bin
# /data/datasets/dataset_kitti/10/lidar/001042.bin
# /data/datasets/dataset_kitti/10/lidar/001043.bin
# /data/datasets/dataset_kitti/10/lidar/001044.bin
# /data/datasets/dataset_kitti/10/lidar/001045.bin
# /data/datasets/dataset_kitti/10/lidar/001046.bin
# /data/datasets/dataset_kitti/10/lidar/001047.bin
# /data/datasets/dataset_kitti/10/lidar/001048.bin
# /data/datasets/dataset_kitti/10/lidar/001049.bin
# /data/datasets/dataset_kitti/10/lidar/001050.bin
# /data/datasets/dataset_kitti/10/lidar/001051.bin
# /data/datasets/dataset_kitti/10/lidar/001052.bin
# /data/datasets/dataset_kitti/10/lidar/001053.bin
# /data/datasets/dataset_kitti/10/lidar/001054.bin
# /data/datasets/dataset_kitti/10/lidar/001055.bin
# /data/datasets/dataset_kitti/10/lidar/001056.bin
# /data/datasets/dataset_kitti/10/lidar/001057.bin
# /data/datasets/dataset_kitti/10/lidar/001058.bin
# /data/datasets/dataset_kitti/10/lidar/001059.bin
# /data/datasets/dataset_kitti/10/lidar/001060.bin
# /data/datasets/dataset_kitti/10/lidar/001061.bin
# /data/datasets/dataset_kitti/10/lidar/001062.bin
# /data/datasets/dataset_kitti/10/lidar/001063.bin
# /data/datasets/dataset_kitti/10/lidar/001064.bin
# /data/datasets/dataset_kitti/10/lidar/001065.bin
# /data/datasets/dataset_kitti/10/lidar/001066.bin
# /data/datasets/dataset_kitti/10/lidar/001067.bin
# /data/datasets/dataset_kitti/10/lidar/001068.bin
# /data/datasets/dataset_kitti/10/lidar/001069.bin
# /data/datasets/dataset_kitti/10/lidar/001070.bin
# /data/datasets/dataset_kitti/10/lidar/001071.bin
# /data/datasets/dataset_kitti/10/lidar/001072.bin
# /data/datasets/dataset_kitti/10/lidar/001073.bin
# /data/datasets/dataset_kitti/10/lidar/001074.bin
# /data/datasets/dataset_kitti/10/lidar/001075.bin
# /data/datasets/dataset_kitti/10/lidar/001076.bin
# /data/datasets/dataset_kitti/10/lidar/001077.bin
# /data/datasets/dataset_kitti/10/lidar/001078.bin
# /data/datasets/dataset_kitti/10/lidar/001079.bin
# /data/datasets/dataset_kitti/10/lidar/001080.bin
# /data/datasets/dataset_kitti/10/lidar/001081.bin
# /data/datasets/dataset_kitti/10/lidar/001082.bin
# /data/datasets/dataset_kitti/10/lidar/001083.bin
# /data/datasets/dataset_kitti/10/lidar/001084.bin
# /data/datasets/dataset_kitti/10/lidar/001085.bin
# /data/datasets/dataset_kitti/10/lidar/001086.bin
# /data/datasets/dataset_kitti/10/lidar/001087.bin
# /data/datasets/dataset_kitti/10/lidar/001088.bin
# /data/datasets/dataset_kitti/10/lidar/001089.bin
# /data/datasets/dataset_kitti/10/lidar/001090.bin
# /data/datasets/dataset_kitti/10/lidar/001091.bin
# /data/datasets/dataset_kitti/10/lidar/001092.bin
# /data/datasets/dataset_kitti/10/lidar/001093.bin
# /data/datasets/dataset_kitti/10/lidar/001094.bin
# /data/datasets/dataset_kitti/10/lidar/001095.bin
# /data/datasets/dataset_kitti/10/lidar/001096.bin
# /data/datasets/dataset_kitti/10/lidar/001097.bin
# /data/datasets/dataset_kitti/10/lidar/001098.bin
# /data/datasets/dataset_kitti/10/lidar/001099.bin
# /data/datasets/dataset_kitti/10/lidar/001100.bin
# /data/datasets/dataset_kitti/10/lidar/001101.bin
# /data/datasets/dataset_kitti/10/lidar/001102.bin
# /data/datasets/dataset_kitti/10/lidar/001103.bin
# /data/datasets/dataset_kitti/10/lidar/001104.bin
# /data/datasets/dataset_kitti/10/lidar/001105.bin
# /data/datasets/dataset_kitti/10/lidar/001106.bin
# /data/datasets/dataset_kitti/10/lidar/001107.bin
# /data/datasets/dataset_kitti/10/lidar/001108.bin
# /data/datasets/dataset_kitti/10/lidar/001109.bin
# /data/datasets/dataset_kitti/10/lidar/001110.bin
# /data/datasets/dataset_kitti/10/lidar/001111.bin
# /data/datasets/dataset_kitti/10/lidar/001112.bin
# /data/datasets/dataset_kitti/10/lidar/001113.bin
# /data/datasets/dataset_kitti/10/lidar/001114.bin
# /data/datasets/dataset_kitti/10/lidar/001115.bin
# /data/datasets/dataset_kitti/10/lidar/001116.bin
# /data/datasets/dataset_kitti/10/lidar/001117.bin
# /data/datasets/dataset_kitti/10/lidar/001118.bin
# /data/datasets/dataset_kitti/10/lidar/001119.bin
# /data/datasets/dataset_kitti/10/lidar/001120.bin
# /data/datasets/dataset_kitti/10/lidar/001121.bin
# /data/datasets/dataset_kitti/10/lidar/001122.bin
# /data/datasets/dataset_kitti/10/lidar/001123.bin
# /data/datasets/dataset_kitti/10/lidar/001124.bin
# /data/datasets/dataset_kitti/10/lidar/001125.bin
# /data/datasets/dataset_kitti/10/lidar/001126.bin
# /data/datasets/dataset_kitti/10/lidar/001127.bin
# /data/datasets/dataset_kitti/10/lidar/001128.bin
# /data/datasets/dataset_kitti/10/lidar/001129.bin
# /data/datasets/dataset_kitti/10/lidar/001130.bin
# /data/datasets/dataset_kitti/10/lidar/001131.bin
# /data/datasets/dataset_kitti/10/lidar/001132.bin
# /data/datasets/dataset_kitti/10/lidar/001133.bin
# /data/datasets/dataset_kitti/10/lidar/001134.bin
# /data/datasets/dataset_kitti/10/lidar/001135.bin
# /data/datasets/dataset_kitti/10/lidar/001136.bin
# /data/datasets/dataset_kitti/10/lidar/001137.bin
# /data/datasets/dataset_kitti/10/lidar/001138.bin
# /data/datasets/dataset_kitti/10/lidar/001139.bin
# /data/datasets/dataset_kitti/10/lidar/001140.bin
# /data/datasets/dataset_kitti/10/lidar/001141.bin
# /data/datasets/dataset_kitti/10/lidar/001142.bin
# /data/datasets/dataset_kitti/10/lidar/001143.bin
# /data/datasets/dataset_kitti/10/lidar/001144.bin
# /data/datasets/dataset_kitti/10/lidar/001145.bin
# /data/datasets/dataset_kitti/10/lidar/001146.bin
# /data/datasets/dataset_kitti/10/lidar/001147.bin
# /data/datasets/dataset_kitti/10/lidar/001148.bin
# /data/datasets/dataset_kitti/10/lidar/001149.bin
# /data/datasets/dataset_kitti/10/lidar/001150.bin
# /data/datasets/dataset_kitti/10/lidar/001151.bin
# /data/datasets/dataset_kitti/10/lidar/001152.bin
# /data/datasets/dataset_kitti/10/lidar/001153.bin
# /data/datasets/dataset_kitti/10/lidar/001154.bin
# /data/datasets/dataset_kitti/10/lidar/001155.bin
# /data/datasets/dataset_kitti/10/lidar/001156.bin
# /data/datasets/dataset_kitti/10/lidar/001157.bin
# /data/datasets/dataset_kitti/10/lidar/001158.bin
# /data/datasets/dataset_kitti/10/lidar/001159.bin
# /data/datasets/dataset_kitti/10/lidar/001160.bin
# /data/datasets/dataset_kitti/10/lidar/001161.bin
# /data/datasets/dataset_kitti/10/lidar/001162.bin
# /data/datasets/dataset_kitti/10/lidar/001163.bin
# /data/datasets/dataset_kitti/10/lidar/001164.bin
# /data/datasets/dataset_kitti/10/lidar/001165.bin
# /data/datasets/dataset_kitti/10/lidar/001166.bin
# /data/datasets/dataset_kitti/10/lidar/001167.bin
# /data/datasets/dataset_kitti/10/lidar/001168.bin
# /data/datasets/dataset_kitti/10/lidar/001169.bin
# /data/datasets/dataset_kitti/10/lidar/001170.bin
# /data/datasets/dataset_kitti/10/lidar/001171.bin
# /data/datasets/dataset_kitti/10/lidar/001172.bin
# /data/datasets/dataset_kitti/10/lidar/001173.bin
# /data/datasets/dataset_kitti/10/lidar/001174.bin
# /data/datasets/dataset_kitti/10/lidar/001175.bin
# /data/datasets/dataset_kitti/10/lidar/001176.bin
# /data/datasets/dataset_kitti/10/lidar/001177.bin
# /data/datasets/dataset_kitti/10/lidar/001178.bin
# /data/datasets/dataset_kitti/10/lidar/001179.bin
# /data/datasets/dataset_kitti/10/lidar/001180.bin
# /data/datasets/dataset_kitti/10/lidar/001181.bin
# /data/datasets/dataset_kitti/10/lidar/001182.bin
# /data/datasets/dataset_kitti/10/lidar/001183.bin
# /data/datasets/dataset_kitti/10/lidar/001184.bin
# /data/datasets/dataset_kitti/10/lidar/001185.bin
# /data/datasets/dataset_kitti/10/lidar/001186.bin
# /data/datasets/dataset_kitti/10/lidar/001187.bin
# /data/datasets/dataset_kitti/10/lidar/001188.bin
# /data/datasets/dataset_kitti/10/lidar/001189.bin
# /data/datasets/dataset_kitti/10/lidar/001190.bin
# /data/datasets/dataset_kitti/10/lidar/001191.bin
# /data/datasets/dataset_kitti/10/lidar/001192.bin
# /data/datasets/dataset_kitti/10/lidar/001193.bin
# /data/datasets/dataset_kitti/10/lidar/001194.bin
# /data/datasets/dataset_kitti/10/lidar/001195.bin
# /data/datasets/dataset_kitti/10/lidar/001196.bin
# /data/datasets/dataset_kitti/10/lidar/001197.bin
# /data/datasets/dataset_kitti/10/lidar/001198.bin
# /data/datasets/dataset_kitti/10/lidar/001199.bin
# /data/datasets/dataset_kitti/10/lidar/001200.bin
# timestamps:  (1201,)
# poses:  (1201, 12)
# N_SCANS: 1201
